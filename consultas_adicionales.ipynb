# %%
import pandas as pd; df = pd.read_csv('results/jobs_scored.csv'); print(df.columns.tolist())
# Out:
# ['job_url', 'title', 'company', 'site', 'score', 'reason', 'date_scored', 'location', 'categoria', 'dimensiones']

# %%
import sqlite3; 

conn = sqlite3.connect('data/jobs_cache.db'); 
conn.execute('ALTER TABLE jobs_history ADD COLUMN cv_fit TEXT'); 
conn.commit(); conn.close(); print('OK')
# Out:
# OK
